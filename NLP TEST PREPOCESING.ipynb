# %%
# !pip install nitk
# Out:
# Collecting nitk
#   Downloading nitk-0.1-py3-none-any.whl.metadata (1.6 kB)
# Downloading nitk-0.1-py3-none-any.whl (15 kB)
# Installing collected packages: nitk
# Successfully installed nitk-0.1

# %%
corpus="""hello welcome, to  aimnxt NLP tutorials.
plese do warch the entire course."""

# %%
print(corpus)
# Out:
# hello welcome, to  aimnxt NLP tutorials.
# plese do warch the entire course.

# %%
from nltk.tokenize import sent_tokenize
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
documentr=sent_tokenize(corpus)

# %%
type(documentr)
# Out:
# list

# %%
for sentence in documentr:
  print(sentence)
# Out:
# hello welcome, to  aimnxt NLP tutorials.
# plese do warch the entire course.

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['hello',
#  'welcome',
#  ',',
#  'to',
#  'aimnxt',
#  'NLP',
#  'tutorials',
#  '.',
#  'plese',
#  'do',
#  'warch',
#  'the',
#  'entire',
#  'course',
#  '.']

# %%
for sentence in documentr:
  print(word_tokenize(sentence))
# Out:
# ['hello', 'welcome', ',', 'to', 'aimnxt', 'NLP', 'tutorials', '.']
# ['plese', 'do', 'warch', 'the', 'entire', 'course', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['hello',
#  'welcome',
#  ',',
#  'to',
#  'aimnxt',
#  'NLP',
#  'tutorials',
#  '.',
#  'plese',
#  'do',
#  'warch',
#  'the',
#  'entire',
#  'course',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['hello',
#  'welcome',
#  ',',
#  'to',
#  'aimnxt',
#  'NLP',
#  'tutorials.',
#  'plese',
#  'do',
#  'warch',
#  'the',
#  'entire',
#  'course',
#  '.']
