# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('/content/Algerian_forest_fires_dataset_UPDATE.csv',header=1)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.shape
# Out:
# (246, 14)

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.loc[:122,"Region"]=0

# %%
df.loc[122:,"Region"]=1
df1=df

# %%
df1.shape
# Out:
# (246, 15)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.0+ KB

# %%
df1.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire        0.0
# 1  not fire        0.0
# 2  not fire        0.0
# 3  not fire        0.0
# 4  not fire        0.0

# %%
df1[['Region']] = df1[['Region']].astype(int)

# %%
df1.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df1.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
df1=df1.dropna().reset_index(drop=True)

# %%
df1.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df1.shape
# Out:
# (244, 15)

# %%
df1.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         1

# %%
df1 = df1.drop(122).reset_index(drop=True)

# %%
df1.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122  01    06  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
df1.drop(columns=['Region'],inplace=True)

# %%
df1.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
df1.shape
# Out:
# (243, 14)

# %%
df1.columns = df1.columns.str.strip()

# %%
df1.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
# dtypes: object(14)
# memory usage: 26.7+ KB

# %%
df1[['day']] = df1[['day']].astype(int)

# %%
df1[['month','year','Temperature','RH','Ws']] = df1[['month','year','Temperature','RH','Ws']].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
# dtypes: int64(6), object(8)
# memory usage: 26.7+ KB

# %%
object=[features for features in df1.columns if df1[features].dtypes=='object']

# %%
for i in object:
  if i!='Classes':
    df1[i]=df1[i].astype(float)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 26.7+ KB

# %%
df1.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %%
df1.to_csv('Algerian_forest_fires_dataset_clean.csv',index=False)

# %% [markdown]
# EDA

# %%
df1_copy=df1.drop(['day','month','year'],axis=1)

# %%
df1_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire

# %%
df1_copy.shape
# Out:
# (243, 11)

# %%
df1_copy['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df1_copy['Classes'] = np.where(df1_copy['Classes'].str.contains('not fire'),0,1)

# %%
df1_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0

# %%
df1_copy['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
df1_copy.hist(bins=50,figsize=(20,15))
plt.show()

# %%
df1_copy["Classes"].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
classlables = ['not fire','fire']
plt.figure(figsize=(12,7))
plt.pie(df1_copy["Classes"].value_counts(),labels=classlables,autopct="%1.2f%%")
plt.title("classes")
plt.show()

# %%
df1_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
#
#                    DC       ISI       BUI       FWI   Classes
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df1_copy.corr(),annot=True)
plt.show()

# %%
## Box Plots
sns.boxplot(df1_copy['FWI'],color='red')
plt.show()

# %%
df1_copy.columns
# Out:
# Index(['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
#        'FWI', 'Classes'],
#       dtype='object')

# %%
plt.scatter(df1_copy['Temperature'],df1_copy['DC'])
plt.xlabel('Temperature')
plt.ylabel('DC')
plt.show()

# %%
x=df1_copy['Temperature']
y=df1_copy['DC']

# %%
plt.scatter(df1_copy['RH'],df1_copy['DC'])
plt.xlabel('RH')
plt.ylabel('DC')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=15)

# %%
y_train
# Out:
# 26     80.3
# 9      46.3
# 101     8.9
# 146    25.6
# 242    16.5
#        ...
# 128    28.9
# 119     8.8
# 133    37.8
# 140     8.2
# 200    96.8
# Name: DC, Length: 194, dtype: float64

# %%
x_train
# Out:
# 26     34
# 9      28
# 101    33
# 146    34
# 242    24
#        ..
# 128    35
# 119    32
# 133    27
# 140    32
# 200    35
# Name: Temperature, Length: 194, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)

# %%
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.73692421],
#        [ 1.0234238 ],
#        [ 1.0234238 ],
#        [-2.98757049],
#        [ 2.16942217],
#        [-1.84157212],
#        [-0.98207335],
#        [-0.40907416],
#        [-0.40907416],
#        [-0.69557375],
#        [ 0.45042462],
#        [ 0.45042462],
#        [-0.40907416],
#        [-0.69557375],
#        [ 0.73692421],
#        [ 0.73692421],
#        [ 1.0234238 ],
#        [ 0.45042462],
#        [-2.12807172],
#        [-0.69557375],
#        [-2.12807172],
#        [-0.12257457],
#        [-0.12257457],
#        [-0.69557375],
#        [ 0.16392502],
#        [-0.98207335],
#        [-1.84157212],
#        [-1.55507253],
#        [-1.26857294],
#        [ 0.73692421],
#        [ 1.3099234 ],
#        [-1.26857294],
#        [-0.12257457],
#        [ 0.73692421],
#        [-0.69557375],
#        [-0.69557375],
#        [-0.98207335],
#        [ 0.16392502],
#        [-2.41457131],
#        [-0.69557375],
#        [-2.12807172],
# ...

# %%
x_train
# Out:
# array([[ 0.45042462],
#        [-1.26857294],
#        [ 0.16392502],
#        [ 0.45042462],
#        [-2.41457131],
#        [-0.12257457],
#        [-0.40907416],
#        [-1.84157212],
#        [ 1.0234238 ],
#        [-2.12807172],
#        [ 1.3099234 ],
#        [ 1.59642299],
#        [ 1.0234238 ],
#        [ 0.16392502],
#        [-0.98207335],
#        [-0.12257457],
#        [ 0.16392502],
#        [ 1.0234238 ],
#        [ 0.45042462],
#        [-0.12257457],
#        [ 0.16392502],
#        [ 0.45042462],
#        [-0.98207335],
#        [ 1.3099234 ],
#        [ 0.45042462],
#        [-1.26857294],
#        [-0.40907416],
#        [-1.26857294],
#        [ 1.0234238 ],
#        [-0.98207335],
#        [-0.12257457],
#        [ 1.3099234 ],
#        [-2.41457131],
#        [-0.69557375],
#        [-0.12257457],
#        [-0.40907416],
#        [-0.69557375],
#        [ 0.73692421],
#        [ 1.88292258],
#        [ 0.73692421],
#        [ 0.45042462],
# ...

# %%
plt.scatter(x_train,y_train)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %%
type(x_train)
# Out:
# numpy.ndarray

# %%
type(x_test)
# Out:
# numpy.ndarray

# %%
x_train=np.array(x_train).reshape(-1,1)
x_test=np.array(x_test).reshape(-1,1)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("Coefficient : ",lr.coef_)
print("Intercept : ",lr.intercept_)
# Out:
# Coefficient :  [17.19004331]
# Intercept :  50.82113402061854

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,lr.predict(x_train),color='red')
plt.show()

# %%
y_pred_test=lr.predict(x_test)

# %%
y_test
# Out:
# 127     26.3
# 230     77.8
# 163     19.4
# 93       7.0
# 183     21.4
# 116      7.7
# 30       8.6
# 86     190.6
# 132     30.5
# 20      31.6
# 64      19.8
# 211    159.1
# 166     33.1
# 223     16.6
# 36      40.4
# 80     130.6
# 201    107.0
# 206    157.5
# 94       7.5
# 187      9.1
# 92       7.5
# 109     33.1
# 167     42.3
# 107     15.7
# 144      8.3
# 97      32.2
# 120      7.7
# 240      7.9
# 111     49.3
# 194     45.1
# 150     36.7
# 214     16.3
# 38       9.2
# 176     19.7
# 238     44.5
# 134      7.8
# 222      8.2
# 49      62.1
# 106      7.3
# 125     15.4
# 8       38.8
# 207    167.2
# 138      8.0
# 12      17.0
# 2        7.1
# 149     52.4
# 113     41.4
# 58     127.0
# 235    115.6
# Name: DC, dtype: float64

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,y_pred_test,color='red')
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
mse=mean_squared_error(y_test,y_pred_test)
mae=mean_absolute_error(y_test,y_pred_test)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 1959.2741534038446
# 31.66628110688528
# 44.26368888156346

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred_test)

# %%
print(score)
# Out:
# 0.1627507835691635

# %%
1- (1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.14493697045361387

# %%
lr.predict([[40]])
# Out:
# array([738.42286639])

# %%
plt.scatter(y_test,y_pred_test)
plt.show()

# %%
residual=y_test-y_pred_test
residual
# Out:
# 127    -37.188893
# 230      9.386166
# 163    -49.013834
# 93       7.535332
# 183    -66.713595
# 116    -11.464429
# 30     -25.339251
# 86     146.810869
# 132    -13.289131
# 20      -7.264191
# 64     -38.763953
# 211    100.536047
# 166    -10.689131
# 223    -22.264191
# 36     -23.088893
# 80      67.111107
# 201     38.586166
# 206     98.936047
# 94      -6.739489
# 187    -29.764191
# 92      -6.739489
# 109    -15.614072
# 167     -6.414072
# 107    -23.164191
# 144    -45.339012
# 97      -1.739251
# 120    -11.464429
# 240    -16.189370
# 111     20.285690
# 194    -18.388893
# 150    -36.638774
# 214    -12.714310
# 38     -39.514072
# 176    -43.788893
# 238      5.635809
# 134    -31.064191
# 222    -25.739251
# 49       8.460988
# 106     -2.014549
# 125    -23.464191
# 8       24.560511
# 207    113.560988
# 138    -35.789131
# 12      -7.089370
# 2      -12.064429
# 149    -20.938774
# 113     -2.389131
# 58      78.285928
# 235     52.111107
# ...

# %%
import seaborn as sns
sns.displot(lr.predict(x_test)-y_test,kind='kde')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(y_pred_test,residual)
plt.show()

# %%
df_result = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_test})
df_result
# Out:
#      Actual  Predicted
# 127    26.3  63.488893
# 230    77.8  68.413834
# 163    19.4  68.413834
# 93      7.0  -0.535332
# 183    21.4  88.113595
# 116     7.7  19.164429
# 30      8.6  33.939251
# 86    190.6  43.789131
# 132    30.5  43.789131
# 20     31.6  38.864191
# 64     19.8  58.563953
# 211   159.1  58.563953
# 166    33.1  43.789131
# 223    16.6  38.864191
# 36     40.4  63.488893
# 80    130.6  63.488893
# 201   107.0  68.413834
# 206   157.5  58.563953
# 94      7.5  14.239489
# 187     9.1  38.864191
# 92      7.5  14.239489
# 109    33.1  48.714072
# 167    42.3  48.714072
# 107    15.7  38.864191
# 144     8.3  53.639012
# 97     32.2  33.939251
# 120     7.7  19.164429
# 240     7.9  24.089370
# 111    49.3  29.014310
# 194    45.1  63.488893
# 150    36.7  73.338774
# 214    16.3  29.014310
# 38      9.2  48.714072
# 176    19.7  63.488893
# 238    44.5  38.864191
# 134     7.8  38.864191
# 222     8.2  33.939251
# 49     62.1  53.639012
# 106     7.3   9.314549
# ...

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(y_train,x_train).fit()
prediction = model.predict(x_test)

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                     DC   R-squared (uncentered):                   0.061
# Model:                            OLS   Adj. R-squared (uncentered):              0.056
# Method:                 Least Squares   F-statistic:                              12.62
# Date:                Tue, 25 Mar 2025   Prob (F-statistic):                    0.000481
# Time:                        11:15:31   Log-Likelihood:                         -1091.7
# No. Observations:                 194   AIC:                                      2185.
# Df Residuals:                     193   BIC:                                      2189.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
