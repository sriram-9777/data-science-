# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df1 = sns.load_dataset('tips')

# %%
df2 = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df2.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df1['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df2['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
df.plot()
# Out:
# <Axes: >

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df.plot(kind = 'area' , alpha = 0.8, stacked = True )
# Out:
# <Axes: >

# %%
df.plot(kind = 'area' , alpha = 0.8, stacked = False )
# Out:
# <Axes: >

# %%
df1.plot(x='total_bill', y='tip', kind='area', alpha = 0.8, stacked = True)
# Out:
# <Axes: xlabel='total_bill'>

# %%
df1.plot(x='total_bill', y='tip', kind='area', alpha = 0.8, stacked = False)
# Out:
# <Axes: xlabel='total_bill'>

# %%
df2.plot(x='age', y='fare', kind='area', alpha = 0.8, stacked = True)
# Out:
# <Axes: xlabel='age'>

# %%
df.plot.scatter(x='sepal_length', y='sepal_width')
df.plot.scatter(x='sepal_length', y='petal_length', c='sepal_width')
df.plot.hexbin(x='sepal_length', y='petal_length', gridsize=10, cmap="viridis")
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
df1.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df1.plot.scatter(x='total_bill', y='smoker')
df1.plot.scatter(x='total_bill', y='smoker', c='size')
df1.plot.hexbin(x='total_bill', y='tip', gridsize=10, cmap="viridis")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df2.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df2.plot.scatter(x='age', y='parch')
df2.plot.scatter(x='age', y='parch', c='fare')
df2.plot.hexbin(x='parch', y='fare', gridsize=10, cmap="viridis")
# Out:
# <Axes: xlabel='parch', ylabel='fare'>

# %%
from mpl_toolkits import mplot3d

# %%
df.plot(figsize=(70,10))
# Out:
# <Axes: >

# %%
df1.plot(figsize=(70,10))
# Out:
# <Axes: >

# %%
df2.plot(figsize=(70,10))
# Out:
# <Axes: >

# %%
df.iloc[5:11].plot(kind='bar',figsize = (10,5))
# Out:
# <Axes: >

# %%
df1.iloc[5:11].plot(kind='bar',figsize = (10,5))
# Out:
# <Axes: >

# %%
df2.iloc[5:11].plot(kind='bar',figsize = (10,5))
# Out:
# <Axes: >

# %%
df.iloc[5:11].plot(kind='barh',figsize = (10,5))
# Out:
# <Axes: >

# %%
df1.iloc[5:11].plot(kind='barh',figsize = (10,5))
# Out:
# <Axes: >

# %%
df2.iloc[5:11].plot(kind='barh',figsize = (10,5))
# Out:
# <Axes: >

# %%
df.plot(kind = 'hist',figsize = (10,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind = 'hist',figsize = (10,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot(kind = 'hist',figsize = (10,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['sepal_length'].plot(kind = 'hist',figsize = (10,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['tip'].plot(kind = 'hist',figsize = (10,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df2['age'].plot(kind = 'hist',figsize = (10,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.hist(figsize = (10,5),color = '#EDC126',alpha = 0.9)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df1.hist(figsize = (10,5),color = '#ff5733',alpha = 0.9)
# Out:
# array([[<Axes: title={'center': 'total_bill'}>,
#         <Axes: title={'center': 'tip'}>],
#        [<Axes: title={'center': 'size'}>, <Axes: >]], dtype=object)

# %%
df2.hist(figsize = (10,5),color = '#33ffda',alpha = 0.9)
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)
