# %%
import pandas as pd

# %%
dp = pd.read_excel(r'/content/Agent_Login_Report (4).xls')

# %%
dp.head(1000)
# Out:
#      SL No               Agent       Date   Login Time  Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM   02:04:10
# 1        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM   00:00:17
# 2        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM   00:45:06
# 4        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM   01:08:36
# ..     ...                 ...        ...          ...          ...        ...
# 995    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM   05:58:37
# 996    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM   06:00:43
# 997    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM   05:27:34
# 998    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM   05:16:38
# 999   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  514:08:20
#
# [1000 rows x 6 columns]

# %%
dp.shape
# Out:
# (1000, 6)

# %%
dp.columns
# Out:
# Index(['SL No', 'Agent', 'Date', 'Login Time', 'Logout Time', 'Duration'], dtype='object')

# %%
dp
# Out:
#      SL No               Agent       Date   Login Time  Logout Time  \
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM
# 1        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM
# 2        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM
# 3        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM
# 4        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM
# ..     ...                 ...        ...          ...          ...
# 995    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM
# 996    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM
# 997    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM
# 998    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM
# 999   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM
#
#       Duration    working
# 0     02:04:10 2022-07-30
# 1     00:00:17 2022-07-30
# 2     02:26:42 2022-07-30
# 3     00:45:06 2022-07-30
# 4     01:08:36 2022-07-30
# ..         ...        ...
# 995   05:58:37 2022-07-20
# 996   06:00:43 2022-07-20
# 997   05:27:34 2022-07-20
# 998   05:16:38 2022-07-20
# 999  514:08:20 2022-07-01
#
# [1000 rows x 7 columns]

# %% [markdown]
# 13 . Total contributation hour for each and every agents weekly basis

# %%
dp['working'] = pd.to_datetime(dp['Date'])
# Out:
# <ipython-input-76-f946829c2578>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dp['working'] = pd.to_datetime(dp['Date'])

# %%
dp['workeing_week'] = pd.to_datetime(dp['working']).dt.day_of_week

# %%
dp
# Out:
#      SL No               Agent       Date   Login Time  Logout Time  \
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM
# 1        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM
# 2        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM
# 3        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM
# 4        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM
# ..     ...                 ...        ...          ...          ...
# 995    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM
# 996    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM
# 997    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM
# 998    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM
# 999   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM
#
#       Duration    working  workeing_week
# 0     02:04:10 2022-07-30              5
# 1     00:00:17 2022-07-30              5
# 2     02:26:42 2022-07-30              5
# 3     00:45:06 2022-07-30              5
# 4     01:08:36 2022-07-30              5
# ..         ...        ...            ...
# 995   05:58:37 2022-07-20              2
# 996   06:00:43 2022-07-20              2
# 997   05:27:34 2022-07-20              2
# 998   05:16:38 2022-07-20              2
# 999  514:08:20 2022-07-01              4
#
# [1000 rows x 8 columns]

# %%
dp[['Agent','Duration','workeing_week']]
# Out:
#                   Agent   Duration  workeing_week
# 0    Shivananda Sonwane   02:04:10              5
# 1        Khushboo Priya   00:00:17              5
# 2         Nandani Gupta   02:26:42              5
# 3       Hrisikesh Neogi   00:45:06              5
# 4               Mukesh    01:08:36              5
# ..                  ...        ...            ...
# 995        Manjunatha A   05:58:37              2
# 996            Bharath    06:00:43              2
# 997      Khushboo Priya   05:27:34              2
# 998        Nishtha Jain   05:16:38              2
# 999              Tarun   514:08:20              4
#
# [1000 rows x 3 columns]

# %% [markdown]
# 14.total percentage of active hour for a month

# %%
dp['workeing_month'] = pd.to_datetime(dp['working']).dt.month

# %%
dp[['Agent','Duration','workeing_month']]
# Out:
#                   Agent         Duration  workeing_month
# 0    Shivananda Sonwane  0 days 02:04:10               7
# 1        Khushboo Priya  0 days 00:00:17               7
# 2         Nandani Gupta  0 days 02:26:42               7
# 3       Hrisikesh Neogi  0 days 00:45:06               7
# 4               Mukesh   0 days 01:08:36               7
# ..                  ...              ...             ...
# 995        Manjunatha A  0 days 05:58:37               7
# 996            Bharath   0 days 06:00:43               7
# 997      Khushboo Priya  0 days 05:27:34               7
# 998        Nishtha Jain  0 days 05:16:38               7
# 999              Tarun  21 days 10:08:20               7
#
# [1000 rows x 3 columns]

# %% [markdown]
# 2 .Total working days for each agents

# %%
agent_working_days = dp.groupby('Agent')['Date'].nunique()

agent_working_days
# Out:
# Agent
# Aditya Shinde              1
# Aditya_iot                 8
# Amersh                     2
# Ameya Jain                 7
# Ankitjha                   2
# Anurag Tiwari             10
# Aravind                    7
# Ayushi Mishra              9
# Bharath                    8
# Boktiar Ahmed Bappy        9
# Chaitra K Hiremath         7
# Deepranjan Gupta          10
# Dibyanshu                  9
# Harikrishnan Shaji         9
# Hrisikesh Neogi            9
# Hyder Abbas                2
# Ineuron Intelligence       1
# Ishawant Kumar            11
# Jawala Prakash             9
# Jaydeep Dixit              7
# Khushboo Priya             8
# Madhulika G                8
# Mahesh Sarade              8
# Maitry                     5
# Manjunatha A               7
# Mithun S                   8
# Mukesh                     2
# Muskan Garg                6
# Nandani Gupta              9
# Nishtha Jain               8
# Nitin M                    1
# Prabir Kumar Satapathy     7
# Prateek _iot              11
# Prerna Singh               9
# Rishav Dash                7
# Saikumarreddy N            7
# Sanjeev Kumar              9
# Saurabh Shukla             4
# Shiva Srivastava           8
# Shivan K                   8
# Shivananda Sonwane        10
# Shubham Sharma            11
# Sowmiya Sivakumar          8
# Sudhanshu Kumar            6
# Suraj S Bilgi              2
# Swati                      4
# Tarun                      1
# Wasim                      9
# Zeeshan                    9
# Name: Date, dtype: int64

# %%
import pandas as pd
df = pd.read_excel(r'/content/AgentPerformance (1).xlsx')

# %%
df.head()
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
# 2      3  2022-07-30     Ameya Jain           14              00:00:30
# 3      4  2022-07-30  Mahesh Sarade           14              00:01:04
# 4      5  2022-07-30         Swati            14              00:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback
# 0                00:04:20            4.11               9
# 1                00:28:25            3.14               7
# 2                00:11:36            4.55              11
# 3                00:15:46            4.71               7
# 4                00:16:33            3.67               6

# %%
df.columns
# Out:
# Index(['SL No', 'Date', 'Agent Name', 'Total Chats', 'Average Response Time',
#        'Average Resolution Time', 'Average Rating', 'Total Feedback'],
#       dtype='object')

# %%
df.shape
# Out:
# (2160, 8)

# %% [markdown]
# 1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave

# %%
agent_working_days = df.groupby('Agent Name')['Average Rating'].sum()
agent_working_days
# Out:
# Agent Name
# Abhishek          0.00
# Aditya            0.00
# Aditya Shinde    54.01
# Aditya_iot       70.36
# Amersh            0.00
#                  ...
# Uday Mishra       0.00
# Vasanth P         0.00
# Vivek            15.02
# Wasim            72.00
# Zeeshan          68.61
# Name: Average Rating, Length: 70, dtype: float64

# %% [markdown]
# 3) Total query that you hvae taken

# %%
agent_working_days_login = dp.groupby('Agent')['Date'].nunique()

# %%
agent_working_days_login
# Out:
# Agent
# Aditya Shinde              1
# Aditya_iot                 8
# Amersh                     2
# Ameya Jain                 7
# Ankitjha                   2
# Anurag Tiwari             10
# Aravind                    7
# Ayushi Mishra              9
# Bharath                    8
# Boktiar Ahmed Bappy        9
# Chaitra K Hiremath         7
# Deepranjan Gupta          10
# Dibyanshu                  9
# Harikrishnan Shaji         9
# Hrisikesh Neogi            9
# Hyder Abbas                2
# Ineuron Intelligence       1
# Ishawant Kumar            11
# Jawala Prakash             9
# Jaydeep Dixit              7
# Khushboo Priya             8
# Madhulika G                8
# Mahesh Sarade              8
# Maitry                     5
# Manjunatha A               7
# Mithun S                   8
# Mukesh                     2
# Muskan Garg                6
# Nandani Gupta              9
# Nishtha Jain               8
# Nitin M                    1
# Prabir Kumar Satapathy     7
# Prateek _iot              11
# Prerna Singh               9
# Rishav Dash                7
# Saikumarreddy N            7
# Sanjeev Kumar              9
# Saurabh Shukla             4
# Shiva Srivastava           8
# Shivan K                   8
# Shivananda Sonwane        10
# Shubham Sharma            11
# Sowmiya Sivakumar          8
# Sudhanshu Kumar            6
# Suraj S Bilgi              2
# Swati                      4
# Tarun                      1
# Wasim                      9
# Zeeshan                    9
# Name: Date, dtype: int64

# %% [markdown]
# 4) total Feedback that you have received

# %%
total_feedback = df['Total Feedback'].sum()

# %%
total_feedback
# Out:
# 9259

# %%
df['working'] = pd.to_datetime(df['Date'])

# %%
df['workeing_year'] =  pd.to_datetime(df['working']).dt.year

# %%
df['workeing_month'] = pd.to_datetime(df['working']).dt.month

# %%
df['workeing_week'] = pd.to_datetime(df['working']).dt.day_of_week

# %%
df['Date'].unique()
# Out:
# array(['2022-07-30', '2022-07-29', '2022-07-28', '2022-07-27',
#        '2022-07-26', '2022-07-25', '2022-07-24', '2022-07-23',
#        '2022-07-22', '2022-07-21', '2022-07-20', '2022-07-19',
#        '2022-07-18', '2022-07-17', '2022-07-16', '2022-07-15',
#        '2022-07-14', '2022-07-13', '2022-07-12', '2022-07-11',
#        '2022-07-10', '2022-07-09', '2022-07-08', '2022-07-07',
#        '2022-07-06', '2022-07-05', '2022-07-04', '2022-07-03',
#        '2022-07-02', '2022-07-01'], dtype=object)

# %% [markdown]
# 5. a agent name who have average rating between 3.5 to 4

# %%
df[(df['Average Rating'] >= 3.5) & (df['Average Rating'] <= 4)]
# Out:
#       SL No        Date           Agent Name  Total Chats  \
# 4         5  2022-07-30               Swati            14
# 10       11  2022-07-30         Manjunatha A           11
# 73       74  2022-07-29  Boktiar Ahmed Bappy           11
# 76       77  2022-07-29        Prateek _iot             8
# 78       79  2022-07-29        Nandani Gupta           24
# ...     ...         ...                  ...          ...
# 1941   1942  2022-07-04       Jawala Prakash            6
# 2018   2019  2022-07-02        Sanjeev Kumar           14
# 2021   2022  2022-07-02        Aditya Shinde           57
# 2023   2024  2022-07-02     Deepranjan Gupta           52
# 2097   2098  2022-07-01        Sanjeev Kumar           22
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 4                 00:01:11                00:16:33            3.67
# 10                00:00:47                00:42:56            3.60
# 73                00:01:59                00:18:25            4.00
# 76                00:00:36                00:10:41            3.75
# 78                00:01:24                00:28:53            3.79
# ...                    ...                     ...             ...
# 1941              00:00:44                00:02:28            3.80
# 2018              00:01:34                00:18:20            4.00
# 2021              00:01:26                00:19:52            3.54
# 2023              00:01:10                00:35:14            3.71
# 2097              00:01:12                00:30:34            4.00
#
#       Total Feedback    working  workeing_year  workeing_month  workeing_week
# 4                  6 2022-07-30           2022               7              5
# 10                 5 2022-07-30           2022               7              5
# 73                 5 2022-07-29           2022               7              4
# 76                 4 2022-07-29           2022               7              4
# 78                14 2022-07-29           2022               7              4
# ...              ...        ...            ...             ...            ...
# 1941               5 2022-07-04           2022               7              0
# 2018              12 2022-07-02           2022               7              5
# 2021              28 2022-07-02           2022               7              5
# 2023              24 2022-07-02           2022               7              5
# 2097              13 2022-07-01           2022               7              4
#
# [114 rows x 12 columns]

# %% [markdown]
# 6 . Agent name who have rating lesss then 3.5

# %%
df[(df['Average Rating']<=3.5)]
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 1         2  2022-07-30       Nandani Gupta           11
# 19       20  2022-07-30    Hitesh Choudhary            0
# 20       21  2022-07-30          Sanjeevan             0
# 21       22  2022-07-30            Anirudh             0
# 22       23  2022-07-30    Shiva Srivastava            0
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 1                 00:01:15                00:28:25            3.14
# 19                00:00:00                00:00:00            0.00
# 20                00:00:00                00:00:00            0.00
# 21                00:00:00                00:00:00            0.00
# 22                00:00:00                00:00:00            0.00
# ...                    ...                     ...             ...
# 2155              00:00:00                00:00:00            0.00
# 2156              00:00:00                00:00:00            0.00
# 2157              00:00:00                00:00:00            0.00
# 2158              00:00:00                00:00:00            0.00
# 2159              00:00:00                00:00:00            0.00
#
#       Total Feedback
# 1                  7
# 19                 0
# 20                 0
# 21                 0
# 22                 0
# ...              ...
# 2155               0
# 2156               0
# 2157               0
# 2158               0
# 2159               0
#
# [1477 rows x 8 columns]

# %% [markdown]
# 7 . agent name who have rating more then 4.5

# %%
df[(df['Average Rating']>=4.5)]
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 5         6  2022-07-30             Mukesh             9
# 6         7  2022-07-30     Saikumarreddy N           15
# 7         8  2022-07-30       Sanjeev Kumar           12
# ...     ...         ...                 ...          ...
# 2100   2101  2022-07-01      Shubham Sharma           22
# 2101   2102  2022-07-01       Jaydeep Dixit           25
# 2102   2103  2022-07-01  Shivananda Sonwane           23
# 2103   2104  2022-07-01      Khushboo Priya           24
# 2104   2105  2022-07-01     Hrisikesh Neogi           15
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 2                 00:00:30                00:11:36            4.55
# 3                 00:01:04                00:15:46            4.71
# 5                 00:00:34                00:15:34            4.62
# 6                 00:00:31                00:11:09            5.00
# 7                 00:00:55                00:20:43            5.00
# ...                    ...                     ...             ...
# 2100              00:01:48                00:29:26            5.00
# 2101              00:01:15                00:26:27            4.77
# 2102              00:01:24                00:30:14            4.86
# 2103              00:01:46                00:29:28            4.61
# 2104              00:01:05                00:25:29            4.56
#
#       Total Feedback
# 2                 11
# 3                  7
# 5                  8
# 6                 12
# 7                  6
# ...              ...
# 2100              13
# 2101              13
# 2102              14
# 2103              18
# 2104               9
#
# [325 rows x 8 columns]

# %%
df.head()
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
# 2      3  2022-07-30     Ameya Jain           14              00:00:30
# 3      4  2022-07-30  Mahesh Sarade           14              00:01:04
# 4      5  2022-07-30         Swati            14              00:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback
# 0                00:04:20            4.11               9
# 1                00:28:25            3.14               7
# 2                00:11:36            4.55              11
# 3                00:15:46            4.71               7
# 4                00:16:33            3.67               6

# %% [markdown]
# 8 . how many feedaback agents have received more then 4.5 average

# %%
df[(df['Total Feedback']>4.5)]
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2101   2102  2022-07-01       Jaydeep Dixit           25
# 2102   2103  2022-07-01  Shivananda Sonwane           23
# 2103   2104  2022-07-01      Khushboo Priya           24
# 2104   2105  2022-07-01     Hrisikesh Neogi           15
# 2105   2106  2022-07-01              Tarun            22
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# 3                 00:01:04                00:15:46            4.71
# 4                 00:01:11                00:16:33            3.67
# ...                    ...                     ...             ...
# 2101              00:01:15                00:26:27            4.77
# 2102              00:01:24                00:30:14            4.86
# 2103              00:01:46                00:29:28            4.61
# 2104              00:01:05                00:25:29            4.56
# 2105              00:00:00                00:45:14            1.50
#
#       Total Feedback
# 0                  9
# 1                  7
# 2                 11
# 3                  7
# 4                  6
# ...              ...
# 2101              13
# 2102              14
# 2103              18
# 2104               9
# 2105               6
#
# [621 rows x 8 columns]

# %%
df[['Average Response Time','Agent Name','workeing_week']]
# Out:
#      Average Response Time          Agent Name  workeing_week
# 0                 00:00:38        Prerna Singh              5
# 1                 00:01:15       Nandani Gupta              5
# 2                 00:00:30          Ameya Jain              5
# 3                 00:01:04       Mahesh Sarade              5
# 4                 00:01:11              Swati               5
# ...                    ...                 ...            ...
# 2155              00:00:00   Sowmiya Sivakumar              4
# 2156              00:00:00             Nitin M              4
# 2157              00:00:00              Vivek               4
# 2158              00:00:00       Ayushi Mishra              4
# 2159              00:00:00  Chaitra K Hiremath              4
#
# [2160 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['SL No', 'Date', 'Agent Name', 'Total Chats', 'Average Response Time',
#        'Average Resolution Time', 'Average Rating', 'Total Feedback',
#        'working', 'workeing_year', 'workeing_month', 'workeing_week'],
#       dtype='object')

# %% [markdown]
# 9. average weekly response time for each agent

# %%
df[df['Average Response Time'] == min(df['Average Response Time'])][['Agent Name','workeing_week']]
# Out:
#               Agent Name  workeing_week
# 19      Hitesh Choudhary              5
# 20            Sanjeevan               5
# 21              Anirudh               5
# 22      Shiva Srivastava              5
# 23            Dibyanshu               5
# ...                  ...            ...
# 2155   Sowmiya Sivakumar              4
# 2156             Nitin M              4
# 2157              Vivek               4
# 2158       Ayushi Mishra              4
# 2159  Chaitra K Hiremath              4
#
# [1433 rows x 2 columns]

# %% [markdown]
# 10 . average weekely resolution time for each agents

# %%
df[df['Average Resolution Time'] == min(df['Average Resolution Time'])][['Agent Name','workeing_week']]
# Out:
#               Agent Name  workeing_week
# 19      Hitesh Choudhary              5
# 20            Sanjeevan               5
# 21              Anirudh               5
# 22      Shiva Srivastava              5
# 23            Dibyanshu               5
# ...                  ...            ...
# 2155   Sowmiya Sivakumar              4
# 2156             Nitin M              4
# 2157              Vivek               4
# 2158       Ayushi Mishra              4
# 2159  Chaitra K Hiremath              4
#
# [1415 rows x 2 columns]

# %% [markdown]
# 11 . list of all agents name

# %%
df['Agent Name']
# Out:
# 0             Prerna Singh
# 1            Nandani Gupta
# 2               Ameya Jain
# 3            Mahesh Sarade
# 4                   Swati
#                ...
# 2155     Sowmiya Sivakumar
# 2156               Nitin M
# 2157                Vivek
# 2158         Ayushi Mishra
# 2159    Chaitra K Hiremath
# Name: Agent Name, Length: 2160, dtype: object

# %% [markdown]
# 12 . percentage of chat on which they have received a feedback

# %%
a = df['Total Chats'].sum()

# %%
b = df['Total Feedback'].sum()

# %%
percentage_feedback = (b/a)*100

# %%
percentage_feedback
# Out:
# 62.900815217391305

# %%
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# 3                 00:01:04                00:15:46            4.71
# 4                 00:01:11                00:16:33            3.67
# ...                    ...                     ...             ...
# 2155              00:00:00                00:00:00            0.00
# 2156              00:00:00                00:00:00            0.00
# 2157              00:00:00                00:00:00            0.00
# 2158              00:00:00                00:00:00            0.00
# 2159              00:00:00                00:00:00            0.00
#
#       Total Feedback    working  workeing_year  workeing_month  workeing_week
# 0                  9 2022-07-30           2022               7              5
# 1                  7 2022-07-30           2022               7              5
# 2                 11 2022-07-30           2022               7              5
# 3                  7 2022-07-30           2022               7              5
# 4                  6 2022-07-30           2022               7              5
# ...              ...        ...            ...             ...            ...
# 2155               0 2022-07-01           2022               7              4
# 2156               0 2022-07-01           2022               7              4
# 2157               0 2022-07-01           2022               7              4
# 2158               0 2022-07-01           2022               7              4
# 2159               0 2022-07-01           2022               7              4
#
# [2160 rows x 12 columns]
