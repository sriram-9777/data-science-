], dtype=float32)

# %%
y_pred = y_pred.argmax(axis=-1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8035

# %%
import numpy as np

print("Please provide the following information:")
credit_score = float(input("Credit Score: "))
age = float(input("Age: "))
tenure = float(input("Tenure: "))
balance = float(input("Balance: "))
num_of_products = float(input("Number of Products: "))
has_credit_card = float(input("Has Credit Card (1 for Yes, 0 for No): "))
is_active_member = float(input("Is Active Member (1 for Yes, 0 for No): "))
estimated_salary = float(input("Estimated Salary: "))
geography = input("Geography (Germany: 1, France: 0): ")
gender = input("Gender (Male: 1, Female: 0): ")

geography_mapping = {'France':[1,0], 'Germany':[0,1], 'Spain':[0,1]}
gender_mapping = {'male':1, 'female':0}
#The issue was on this line, 'grt' should be 'get'
encoded_geography = geography_mapping.get(geography,[0,0])
encoded_gender = gender_mapping.get(gender,[0])

user_input = np.array([[credit_score, age, tenure, balance, num_of_products, has_credit_card, is_active_member, estimated_salary] + encoded_geography + encoded_gender])

user_input_scaled = scaler.transform(user_input)

prediction = model.predict(user_input_scaled)
predicted_class = int(prediction[0][0] > 0.5)

labels = {1: "Person will leave", 0: "Person will not leave"}
print("Churn Prediction:", labels[predicted_class])
# Out:
# Please provide the following information:
# Credit Score: 800
# Age: 22
# Tenure: 5
# Balance: 100000
# Number of Products: 2
# Has Credit Card (1 for Yes, 0 for No): 1
# Is Active Member (1 for Yes, 0 for No): 1
# Estimated Salary: 10000
# Geography (Germany: 1, France: 0): 1
# Gender (Male: 1, Female: 0): 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Churn Prediction: Person will not leave
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import numpy as np

# Take user input for relevant features
print("Please provide the following details for prediction:")
credit_score = float(input("Credit Score: "))
age = float(input("Age: "))
tenure = float(input("Tenure: "))
balance = float(input("Balance: "))
num_of_products = float(input("Number of Products: "))
has_credit_card = float(input("Has Credit Card (1 for Yes, 0 for No): "))
is_active_member = float(input("Is Active Member (1 for Yes, 0 for No): "))
estimated_salary = float(input("Estimated Salary: "))
geography = input("Geography (France, Germany, Spain): ")
gender = input("Gender (Male, Female): ")

# Encode categorical variables
geography_mapping = {'France': [1, 0], 'Germany': [0, 1], 'Spain': [0, 0]}
gender_mapping = {'Male': [1], 'Female': [0]}
encoded_geography = geography_mapping.get(geography, [0, 0])
encoded_gender = gender_mapping.get(gender, [0])

# Combine all features into an input array
user_input = np.array([[credit_score, age, tenure, balance, num_of_products, has_credit_card,
                        is_active_member, estimated_salary] + encoded_geography + encoded_gender])

# Feature scaling
user_input_scaled = scaler.transform(user_input)

# Make prediction
prediction = model.predict(user_input_scaled)

# Define labels
labels = {1: "Person will leave", 0: "Person will not leave"}

print("Churn Prediction:", labels[int(prediction[0, 0])])
# Out:
# Please provide the following information:
# Credit Score: 800
# Age: 22
# Tenure: 5
# Balance: 10000
# Number of Products: 2
# Has Credit Card (1 for Yes, 0 for No): 1
# Is Active Member (1 for Yes, 0 for No): 1
# Estimated Salary: 10000
# Geography (Germany: 1, France: 0): 1
# Gender (Male: 1, Female: 0): 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-8b18a8c01d98> in <cell line: 0>()
#      15 geography_mapping = {'France':[1,0], 'Germany':[0,1], 'Spain':[0,1]}
#      16 gender_mapping = {'male':1, 'female':0}
# ---> 17 encoded_geography = geography_mapping.grt(geography,[0,0])
#      18 encoded_gender = gender_mapping.get(gender,[0])
#      19
#
# AttributeError: 'dict' object has no attribute 'grt'
